# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import dask.dataframe as dd
import sys
import os

# %%
# Add the directory containing the Python file to the module search path
sys.path.append('/Users/carlopalazzi/Programming/shipping_sprint/gpo_transitions/Legacy_Global_Port_Optimisation/')
# Note: sys.path works for modules but not files

# Now you can import the desired functions or classes from the Python file
import p_toolbox as toolbox
import p_plot_results as plot_results

from shapely.geometry import Point, LineString
import numpy as np
import warnings

# %%
# Get the current working directory
current_dir = os.getcwd()
# Construct the absolute file path of the Excel file based on the current directory
base_file_path = os.path.join(current_dir, '../../results/2040_sc4.5_df1_sn4000_fpdf1.xlsx')
transport_file_path = os.path.join(current_dir, '../../results/uk_added_demand/transport/2040_sc4.5_df1_fpdf1_uktr.png')


df = pd.read_excel(base_file_path,sheet_name='Demand')

# %%
plot_results.plot_map(base_file_path, save_fig=True, line_scaling=5E4, point_scaling=5E4,
            line_power=0.6, point_power=0.8, output_file_name='uk_map')
# Out:
# Loading in shipping route paths...
# Getting the port information...
# /Users/carlopalazzi/Programming/shipping_sprint/gpo_transitions/Legacy_Global_Port_Optimisation/p_plot_results.py:194: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Gathering the data for the maritime routes and ports...
# Correcting duplicated weights...
# Creating the maritime plotting gpds...
# Gathering the data for the land locations...
# /Users/carlopalazzi/Programming/shipping_sprint/gpo_transitions/Legacy_Global_Port_Optimisation/p_plot_results.py:161: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
